# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
red_df = pd.read_csv('/kaggle/input/wine-quality-selection/winequality-red.csv')
red_df

# %%
red_df.describe()

# %%
# Plot histograms of each feature
red_df.hist(bins=30, figsize=(20,15))
plt.tight_layout()
plt.show()

# Plot scatter matrix of all features
pd.plotting.scatter_matrix(red_df, figsize=(20,15))
plt.show()

# %%
# Scale the features using StandardScaler
scaler = StandardScaler()
scaled_features = scaler.fit_transform(red_df.drop('quality', axis=1))

# %%
# Train the KMeans model
kmeans = KMeans(n_clusters=6)
kmeans.fit(scaled_features)

# %%
# Predict the cluster for each sample
predicted_clusters = kmeans.predict(scaled_features)

# %%
# Add the cluster predictions to the DataFrame
red_df['cluster'] = predicted_clusters

# %%
red_df
